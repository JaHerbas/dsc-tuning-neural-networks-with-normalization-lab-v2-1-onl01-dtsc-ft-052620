# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
pd.set_option('max_columns', None)

# %%
data = pd.read_csv('Housing_Prices/train.csv')

data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Create X and y
y = data[['SalePrice']]
X = data.drop(columns=['SalePrice', 'Id'], axis=1)

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Save y
y_train.to_csv('data/y_train.csv', index=False)
y_val.to_csv('data/y_val.csv', index=False)
y_test.to_csv('data/y_test.csv', index=False)

# %%
# Remove "object"-type features from X
cont_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]

# Remove "object"-type features from X_train and X_test
X_train_cont = X_train.loc[:, cont_features]
X_val_cont = X_val.loc[:, cont_features]
X_test_cont = X_test.loc[:, cont_features]

# Impute missing values with median using SimpleImputer
impute = SimpleImputer(strategy='median')
X_train_numeric = pd.DataFrame(impute.fit_transform(X_train_cont), columns=cont_features)
X_val_numeric = pd.DataFrame(impute.transform(X_val_cont), columns=cont_features)
X_test_numeric = pd.DataFrame(impute.transform(X_test_cont), columns=cont_features)

# %%
# Save numeric X
X_train_numeric.to_csv('data/X_train_numeric.csv', index=False)
X_val_numeric.to_csv('data/X_val_numeric.csv', index=False)
X_test_numeric.to_csv('data/X_test_numeric.csv', index=False)

# %%
# Create X_cat which contains only the categorical variables
features_cat = [col for col in X.columns if X[col].dtype in [np.object]]
X_train_cat = X_train.loc[:, features_cat]
X_val_cat = X_val.loc[:, features_cat]
X_test_cat = X_test.loc[:, features_cat]

# Fill missing values with the string 'missing'
X_train_cat.fillna(value='missing', inplace=True)
X_val_cat.fillna(value='missing', inplace=True)
X_test_cat.fillna(value='missing', inplace=True)

# %%
# OneHotEncode categorical variables
ohe = OneHotEncoder(handle_unknown='ignore')

# Transform training and test sets
X_train_ohe = ohe.fit_transform(X_train_cat)
X_val_ohe = ohe.transform(X_val_cat)
X_test_ohe = ohe.transform(X_test_cat)

# Convert these columns into a DataFrame 
cat_columns = ohe.get_feature_names(input_features=X_train_cat.columns)
X_train_cat = pd.DataFrame(X_train_ohe.todense(), columns=cat_columns)
X_val_cat = pd.DataFrame(X_val_ohe.todense(), columns=cat_columns)
X_test_cat = pd.DataFrame(X_test_ohe.todense(), columns=cat_columns)

# %%
# Save categorical X
X_train_cat.to_csv('data/X_train_cat.csv', index=False)
X_val_cat.to_csv('data/X_val_cat.csv', index=False)
X_test_cat.to_csv('data/X_test_cat.csv', index=False)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train.head().append(X_train.tail())
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 120           80       RL          NaN    21453   Pave   NaN      IR1
# 1410          60       RL         79.0    12420   Pave   NaN      Reg
# 22            20       RL         75.0     9742   Pave   NaN      Reg
# 730          120       RL         39.0     5389   Pave   NaN      IR1
# 1442          60       FV         85.0    11003   Pave   NaN      Reg
# 1321          20       RL          NaN     6627   Pave   NaN      IR1
# 112           60       RL         77.0     9965   Pave   NaN      Reg
# 805           20       RL         91.0    12274   Pave   NaN      IR1
# 412           20       FV          NaN     4403   Pave   NaN      IR2
# 854           20       RL        102.0    17920   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 120          Low    AllPub   CulDSac       Sev      ClearCr       Norm
# 1410         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 22           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 730          Lvl    AllPub    Inside       Gtl      StoneBr       Norm
# 1442         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1321         Lvl    AllPub    Corner       Gtl      BrkSide      Feedr
# 112          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 805          Lvl    AllPub       FR2       Gtl      Somerst       Norm
# 412          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 854          Lvl    AllPub    Inside       Gtl       Sawyer       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 120        Norm     1Fam       SLvl            6            5       1969
# 1410       Norm     1Fam     2Story            7            5       2001
# 22         Norm     1Fam     1Story            8            5       2002
# 730        Norm   TwnhsE     1Story            8            5       1995
# 1442       Norm     1Fam     2Story           10            5       2008
# 1321       Norm     1Fam     1Story            3            6       1949
# 112        Norm     1Fam     2Story            7            5       2007
# 805        Norm     1Fam     1Story            7            5       2008
# 412        Norm     1Fam     1Story            7            5       2009
# 854        Norm     1Fam     1Story            5            4       1955
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 120           1969      Flat    Metal     Plywood     Plywood       None
# 1410          2001     Gable  CompShg     VinylSd     VinylSd       None
# 22            2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 730           1996     Gable  CompShg     CemntBd     CmentBd       None
# 1442          2008     Gable  CompShg     VinylSd     VinylSd      Stone
# 1321          1950       Hip  CompShg     VinylSd     VinylSd       None
# 112           2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 805           2008     Gable  CompShg     VinylSd     VinylSd      Stone
# 412           2009     Gable  CompShg     MetalSd     MetalSd      Stone
# 854           1974       Hip  CompShg     Wd Sdng     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 120          0.0        TA        TA     CBlock       TA       TA
# 1410         0.0        Gd        TA      PConc       Gd       TA
# 22         281.0        Gd        TA      PConc       Gd       TA
# 730          0.0        Gd        TA      PConc       Gd       TA
# 1442       160.0        Ex        TA      PConc       Ex       TA
# 1321         0.0        TA        TA     CBlock      NaN      NaN
# 112        220.0        Gd        TA      PConc       Ex       TA
# 805        256.0        Gd        TA      PConc       Gd       TA
# 412        432.0        Ex        TA      PConc       Ex       TA
# 854          0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 120            Gd          ALQ         938          Unf           0
# 1410           No          GLQ         666          Unf           0
# 22             No          Unf           0          Unf           0
# 730            No          GLQ        1180          Unf           0
# 1442           Av          GLQ         765          Unf           0
# 1321          NaN          NaN           0          NaN           0
# 112            Av          GLQ         984          Unf           0
# 805            No          Unf           0          Unf           0
# 412            Av          GLQ         578          Unf           0
# 854            Mn          ALQ         306          Rec        1085
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 120           0          938    GasA        Ex          Y      SBrkr
# 1410        278          944    GasA        Ex          Y      SBrkr
# 22         1777         1777    GasA        Ex          Y      SBrkr
# 730         415         1595    GasA        Ex          Y      SBrkr
# 1442        252         1017    GasA        Ex          Y      SBrkr
# 1321          0            0   Floor        TA          N      SBrkr
# 112         280         1264    GasA        Ex          Y      SBrkr
# 805        1417         1417    GasA        Ex          Y      SBrkr
# 412         892         1470    GasA        Ex          Y      SBrkr
# 854         372         1763    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 120        988         0             0        988             1             0
# 1410       944       896             0       1840             1             0
# 22        1795         0             0       1795             0             0
# 730       1616         0             0       1616             1             0
# 1442      1026       981             0       2007             1             0
# 1321       720         0             0        720             0             0
# 112       1282      1414             0       2696             1             0
# 805       1428         0             0       1428             0             0
# 412       1478         0             0       1478             1             0
# 854       1779         0             0       1779             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 120          1         0             1             1          TA
# 1410         2         1             3             1          Gd
# 22           2         0             3             1          Gd
# 730          2         0             2             1          Gd
# 1442         2         1             3             1          Ex
# 1321         1         0             2             1          TA
# 112          2         1             4             1          Ex
# 805          2         0             3             1          Ex
# 412          2         1             2             1          Gd
# 854          1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 120              4        Typ           2          TA     Attchd       1969.0
# 1410             6        Typ           0         NaN     Attchd       2001.0
# 22               7        Typ           1          Gd     Attchd       2002.0
# 730              5        Typ           1          TA     Attchd       1995.0
# 1442            10        Typ           1          Ex     Attchd       2008.0
# 1321             4        Typ           0         NaN     Detchd       1955.0
# 112             10        Typ           1          Gd    BuiltIn       2007.0
# 805              6        Typ           0         NaN     Attchd       2008.0
# 412              7        Typ           1          Gd     Attchd       2009.0
# 854              6        Typ           1          Gd     Attchd       1955.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 120           Unf           2         540         TA         TA          Y
# 1410          RFn           2         622         TA         TA          Y
# 22            RFn           2         534         TA         TA          Y
# 730           RFn           2         608         TA         TA          Y
# 1442          Fin           3         812         TA         TA          Y
# 1321          Unf           1         287         TA         Fa          Y
# 112           Fin           3         792         TA         TA          Y
# 805           RFn           2         554         TA         TA          Y
# 412           Fin           2         484         TA         TA          Y
# 854           Unf           2         454         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 120            0          130              0        130            0
# 1410           0           45              0          0            0
# 22           171          159              0          0            0
# 730          237          152              0          0            0
# 1442         168           52              0          0            0
# 1321           0            0              0          0            0
# 112          120          184              0          0          168
# 805            0           60              0          0            0
# 412            0          144              0          0            0
# 854            0          418              0          0          312
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 120          0    NaN   NaN         NaN        0      10    2006       WD
# 1410         0    NaN   NaN         NaN        0       6    2009       WD
# 22           0    NaN   NaN         NaN        0       9    2008       WD
# 730          0    NaN   NaN         NaN        0       3    2010       WD
# 1442         0    NaN   NaN         NaN        0       4    2009       WD
# 1321         0    NaN   NaN         NaN        0       7    2008       WD
# 112          0    NaN   NaN         NaN        0      10    2007      New
# 805          0    NaN   NaN         NaN        0       7    2008      New
# 412          0    NaN   NaN         NaN        0       6    2010      New
# 854          0    NaN   NaN         NaN        0       7    2006       WD
#
#      SaleCondition
# 120         Normal
# 1410        Normal
# 22          Normal
# 730         Normal
# 1442        Normal
# 1321        Normal
# 112        Partial
# 805        Partial
# 412        Partial
# 854        Abnorml

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1051 entries, 120 to 854
# Data columns (total 79 columns):
# MSSubClass       1051 non-null int64
# MSZoning         1051 non-null object
# LotFrontage      857 non-null float64
# LotArea          1051 non-null int64
# Street           1051 non-null object
# Alley            69 non-null object
# LotShape         1051 non-null object
# LandContour      1051 non-null object
# Utilities        1051 non-null object
# LotConfig        1051 non-null object
# LandSlope        1051 non-null object
# Neighborhood     1051 non-null object
# Condition1       1051 non-null object
# Condition2       1051 non-null object
# BldgType         1051 non-null object
# HouseStyle       1051 non-null object
# OverallQual      1051 non-null int64
# OverallCond      1051 non-null int64
# YearBuilt        1051 non-null int64
# YearRemodAdd     1051 non-null int64
# RoofStyle        1051 non-null object
# RoofMatl         1051 non-null object
# Exterior1st      1051 non-null object
# Exterior2nd      1051 non-null object
# MasVnrType       1045 non-null object
# MasVnrArea       1045 non-null float64
# ExterQual        1051 non-null object
# ExterCond        1051 non-null object
# Foundation       1051 non-null object
# BsmtQual         1028 non-null object
# BsmtCond         1028 non-null object
# BsmtExposure     1027 non-null object
# BsmtFinType1     1028 non-null object
# BsmtFinSF1       1051 non-null int64
# BsmtFinType2     1028 non-null object
# BsmtFinSF2       1051 non-null int64
# BsmtUnfSF        1051 non-null int64
# TotalBsmtSF      1051 non-null int64
# Heating          1051 non-null object
# HeatingQC        1051 non-null object
# CentralAir       1051 non-null object
# Electrical       1050 non-null object
# 1stFlrSF         1051 non-null int64
# 2ndFlrSF         1051 non-null int64
# LowQualFinSF     1051 non-null int64
# GrLivArea        1051 non-null int64
# BsmtFullBath     1051 non-null int64
# BsmtHalfBath     1051 non-null int64
# FullBath         1051 non-null int64
# HalfBath         1051 non-null int64
# BedroomAbvGr     1051 non-null int64
# KitchenAbvGr     1051 non-null int64
# KitchenQual      1051 non-null object
# TotRmsAbvGrd     1051 non-null int64
# Functional       1051 non-null object
# Fireplaces       1051 non-null int64
# FireplaceQu      573 non-null object
# GarageType       993 non-null object
# GarageYrBlt      993 non-null float64
# GarageFinish     993 non-null object
# GarageCars       1051 non-null int64
# GarageArea       1051 non-null int64
# GarageQual       993 non-null object
# GarageCond       993 non-null object
# PavedDrive       1051 non-null object
# WoodDeckSF       1051 non-null int64
# OpenPorchSF      1051 non-null int64
# EnclosedPorch    1051 non-null int64
# 3SsnPorch        1051 non-null int64
# ScreenPorch      1051 non-null int64
# PoolArea         1051 non-null int64
# PoolQC           4 non-null object
# Fence            201 non-null object
# MiscFeature      39 non-null object
# MiscVal          1051 non-null int64
# MoSold           1051 non-null int64
# YrSold           1051 non-null int64
# SaleType         1051 non-null object
# SaleCondition    1051 non-null object
# dtypes: float64(3), int64(33), object(43)
# memory usage: 656.9+ KB

# %%
X_train.isna().sum().sum()
# Out:
# 4982
